# %% [markdown]
# # PYTHON TUTORIAL

# %% [markdown]
# ## BASICS OF PYTHON

# %% [markdown]
# #### DataTypes

# %% [markdown]
# - In general or by default the a variable datatype in python is string

# %% [markdown]
# Some of the important datatypes in python are

# %% [markdown]
# - integer
# - string
# - float

# %% [markdown]
# # Arithmetic Operations in python

# %% [markdown]
#  - Addition operator and Subtraction Operator

# %%
1+5
# Out:
# 6

# %%
2-8
# Out:
# -6

# %% [markdown]
# - Multiplication Operator

# %%
4*15
# Out:
# 60

# %% [markdown]
# - Division Operator

# %%
15/3
# Out:
# 5.0

# %% [markdown]
# - Modulus Operator

# %%
100%3
# Out:
# 1

# %% [markdown]
# - Exponentional Operator

# %%
15 ** 2
# Out:
# 225

# %%
10* 'Ammu '
# Out:
# 'Ammu Ammu Ammu Ammu Ammu Ammu Ammu Ammu Ammu Ammu '

# %% [markdown]
# ## How to print a type of the variable in python?

# %% [markdown]
# - We use 'type' keyword to print type

# %%
# Check the data types

# %%
type (3)
# Out:
# int

# %%
type (5.0)
# Out:
# float

# %%
type("Hello")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## Strings

# %% [markdown]
# - Strings are sequence of characters.
# - We represents strings in either double quotes("") or single quotes ('')
# - Strings are immutable

# %%
"Hii Everyone!"
# Out:
# 'Hii Everyone!'

# %%
"This is Amrutha "
# Out:
# 'This is Amrutha '

# %%
type ("Amrutha")
# Out:
# str

# %% [markdown]
# ## Variable Assignment

# %%
#syntax
#variable_name=value
a=10
print(a)
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a=10
b=15

#Mathematical Operations on variables a and b
print(a+b)
print(a-b)
print(a*b)
print(a%b)
print((a+b)/(b-a))#BODMAS
# Out:
# 25
# -5
# 150
# 10
# 5.0

# %%
first_name="Amrutha"
last_name='Chevvuri'

# %%
print("My First name is {} and last name is {}".format(first_name,last_name))
# Out:
# My First name is Amrutha and last name is Chevvuri

# %% [markdown]
# ## What is Formatting in python?

# %% [markdown]
# - In Python, string formatting is used to insert values into placeholders within a string to create dynamic text.
# ### Syntax
# ### f"text {variable} text"
# ### "text {} text".format(variable)

# %%
print("My First name is {first} and last name is {last}".format(first=first_name,last=last_name))
# Out:
# My First name is Amrutha and last name is Chevvuri

# %%
#Length returns length of a variable
#Syntax 
#len(string)
len("Ammu")
# Out:
# 4

# %% [markdown]
# # Python Data Structures and Boolean

# %% [markdown]
# - Boolean
# - Boolean and Logical Operators
# - lists
# - Comparsion Operators
# - Dictionaries
# - Tuples
# - Sets

# %% [markdown]
# ## Boolean Variables
#   - Boolean vaules are the constant objects False and True
#   - They used to represent truth values
#  - When they used in arithmetic operator , they behave like the integers 0-False and 1-     True
#    - The built-in function bool() be used to cast any value to Boolean,If thr value is interpreted as a truth value

# %%
True
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
False
# Out:
# False

# %%
str="Amrutha123"

# %%
str.isalnum() # check if all chara are characters and numbers
# Out:
# True

# %%
str.isdigit() # check if string contains numbers
# Out:
# False

# %%
print(str.isalpha()) #check if all char in the string are alphabetic
print(str.istitle()) #check if string contain title words(Capotal words)
print(str.isupper()) #check if string is in uppercase
print(str.islower()) #check if string is in lowercase
print(str.isspace()) #check if string contains spaces
print(str.endswith("a"))#check if string endswith a
print(str.startswith("A"))#check if string starts with A
# Out:
# False
# True
# False
# False
# False
# False
# True

# %% [markdown]
# ### Boolean and Logical Operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
example="Hello World"
my_str="Ammmu"

# %%
 my_str.isalpha() or example.isnum()
# Out:
# True

# %% [markdown]
# ## Lists

# %% [markdown]
# - List is a built-in data struture used to store an orderd collection of items. They are dynamic,resizable and capable of storing multiple data types
# - They are :
# - mutuable
# - Ordered
# - Index- Based

# %%
lst=['Hi','Hello',15,22,5.0]

# %%
type(lst)
# Out:
# list

# %%
# Creating empty list
l=list()

# %%
len(lst)
# Out:
# 5

# %% [markdown]
# #### In-built  Funtiond of List

# %% [markdown]
# #### Append

# %%
# append is used to add an element to the end of list
lst.append('Python')
lst
# Out:
# ['Hi', 'Hello', 15, 22, 5.0, 'Python']

# %%
lst.append([1,2])

# %%
lst
# Out:
# ['Hi', 'Hello', 15, 22, 5.0, 'Python', [1, 2]]

# %% [markdown]
# #### Insert

# %%
# inserts element at a specific index
lst.insert(6,"Programming")

# %%
lst
# Out:
# ['Hi', 'Hello', 15, 22, 5.0, 'Python', 'Programming', [1, 2]]

# %%
# indexing in list
lst[5]
# Out:
# 'Python'

# %%
lst[4:]
# Out:
# [5.0, 'Python', 'Programming', [1, 2]]

# %%
lst[1:4]
# Out:
# ['Hello', 15, 22]

# %% [markdown]
# #### Extend
# - Extend list by appending elements from the iterable.

# %%
lst=[1,2,3,4,5]

# %%
lst.extend([6,7,8])

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# #### Various operations on Lists
# ##### pop
# - Remove and return item at index (default last)

# %%
lst.pop()
# Out:
# 8

# %%
lst.pop(3)
# Out:
# 4

# %% [markdown]
# #### Count(): Calculates total occurance of given element of list

# %%
lst=[1,1,2,3,4,5]
lst.count(1)
# Out:
# 2

# %%
lst.index(1,0,4)
# Out:
# 0

# %%
min(lst)
# Out:
# 1

# %%
max(lst)
# Out:
# 5
